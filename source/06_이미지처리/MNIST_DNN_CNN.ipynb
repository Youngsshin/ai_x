# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror{font-family:Consolas; font-size:15pt;}
div.output{font-size:12pt; font-weight:bold;}
div.input{font-family:Consolas; font-size:12pt;}
div.prompt{min-width:70px;}
div#toc-wrapper {padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror{font-family:Consolas; font-size:15pt;}
# div.output{font-size:12pt; font-weight:bold;}
# div.input{font-family:Consolas; font-size:12pt;}
# div.prompt{min-width:70px;}
# div#toc-wrapper {padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.datasets import mnist # mnist 훈련셋과 테스트셋
from tensorflow.keras.utils import to_categorical # 원핫인코딩
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout
from matplotlib import pyplot as plt # 학습과정 loss와 acc 시각화

# %%
# 1. 데이터 셋
width = 28; height = 28
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
plt_row = 3
plt_col = 10
# plt.figure(figsize=(plt_col, plt_row))
plt.rcParams['figure.figsize'] = [plt_col, plt_row]
plt.rc("font", family="Malgun Gothic") # window에서 한글 시각화
# plt.rc("font", family="NanumBarunGothic") # 코랩에서 한글 시각화
fig, axes = plt.subplots(plt_row, plt_col)
# axes[0, 0].imshow(X_test[0].reshape(width, height))
# axes[0, 0].axis('off')
# title = "실제:{}".format(y_test[0])
# axes[0, 0].set_title(title)
# plt.subplots_adjust(hspace=0.4, wspace=0.3)
for i in range(plt_row*plt_col):
    subax = axes[i//plt_col, i%plt_col] # // : 몫연산자, % : 나머지연산자
    subax.imshow(X_test[i].reshape(width, height))
    subax.axis('off')
    title = "실제:{}".format(y_test[i])
    subax.set_title(title)
plt.tight_layout()

# %% [markdown]
# # 1. DNN

# %%
# %%time
# 1. 데이터 생성 및 전처리
width = 28; height = 28
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_val = X_train[50000:]
y_val = y_train[50000:]
X_train = X_train[:50000]
y_train = y_train[:50000]
# 독립변수 (28,28) => 784 1차원으로 -> 실수형변환 -> 스케일조정
X_train = X_train.reshape(-1, width*height).astype('float32')/255.0
X_val = X_val.reshape(-1, width*height).astype('float32')/255.0
X_test = X_test.reshape(-1, width*height).astype('float32')/255.0
# 타겟변수 원핫인코딩
Y_train = to_categorical(y_train)
Y_val = to_categorical(y_val)
Y_test = to_categorical(y_test)

X_train.shape, Y_train.shape, X_val.shape, Y_val.shape, X_test.shape, Y_test.shape

# 2. 모델 구성
model = Sequential([
    Input(shape=(width*height,)),
    Dense(units=1024, activation='relu'),
    Dropout(0.3),
    Dense(units=512, activation='relu'),
    Dropout(0.3),
    Dense(units=256, activation='relu'),
    Dropout(0.2),
    Dense(units=10, activation='softmax')
])
# model.summary()
# 3. 학습설정
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# 4. 학습
model.fit(X_train, Y_train, epochs=50,
          validation_data=(X_val, Y_val),
          verbose=1)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.2657 - accuracy: 0.9187 - val_loss: 0.1268 - val_accuracy: 0.9625
# Epoch 2/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.1394 - accuracy: 0.9589 - val_loss: 0.0902 - val_accuracy: 0.9735
# Epoch 3/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.1135 - accuracy: 0.9667 - val_loss: 0.0807 - val_accuracy: 0.9751
# Epoch 4/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0958 - accuracy: 0.9722 - val_loss: 0.0894 - val_accuracy: 0.9775
# Epoch 5/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0834 - accuracy: 0.9760 - val_loss: 0.0818 - val_accuracy: 0.9772
# Epoch 6/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0740 - accuracy: 0.9784 - val_loss: 0.0868 - val_accuracy: 0.9763
# Epoch 7/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0704 - accuracy: 0.9797 - val_loss: 0.0814 - val_accuracy: 0.9786
# Epoch 8/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0637 - accuracy: 0.9808 - val_loss: 0.0833 - val_accuracy: 0.9795
# Epoch 9/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0602 - accuracy: 0.9833 - val_loss: 0.1101 - val_accuracy: 0.9741
# Epoch 10/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0579 - accuracy: 0.9841 - val_loss: 0.0845 - val_accuracy: 0.9799
# Epoch 11/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0542 - accuracy: 0.9846 - val_loss: 0.0954 - val_accuracy: 0.9790
# Epoch 12/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0511 - accuracy: 0.9853 - val_loss: 0.0954 - val_accuracy: 0.9803
# Epoch 13/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0530 - accuracy: 0.9854 - val_loss: 0.0881 - val_accuracy: 0.9811
# Epoch 14/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0435 - accuracy: 0.9879 - val_loss: 0.0985 - val_accuracy: 0.9821
# Epoch 15/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0478 - accuracy: 0.9870 - val_loss: 0.0971 - val_accuracy: 0.9817
# Epoch 16/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0454 - accuracy: 0.9870 - val_loss: 0.1046 - val_accuracy: 0.9798
# Epoch 17/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0437 - accuracy: 0.9886 - val_loss: 0.1144 - val_accuracy: 0.9793
# Epoch 18/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0437 - accuracy: 0.9887 - val_loss: 0.1175 - val_accuracy: 0.9804
# Epoch 19/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0457 - accuracy: 0.9879 - val_loss: 0.0912 - val_accuracy: 0.9812
# Epoch 20/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0365 - accuracy: 0.9902 - val_loss: 0.1155 - val_accuracy: 0.9806
# Epoch 21/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0431 - accuracy: 0.9893 - val_loss: 0.1026 - val_accuracy: 0.9818
# Epoch 22/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0448 - accuracy: 0.9891 - val_loss: 0.0951 - val_accuracy: 0.9814
# Epoch 23/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0365 - accuracy: 0.9907 - val_loss: 0.1184 - val_accuracy: 0.9810
# Epoch 24/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0389 - accuracy: 0.9899 - val_loss: 0.1240 - val_accuracy: 0.9827
# Epoch 25/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0364 - accuracy: 0.9910 - val_loss: 0.1181 - val_accuracy: 0.9819
# Epoch 26/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0389 - accuracy: 0.9902 - val_loss: 0.1129 - val_accuracy: 0.9820
# Epoch 27/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0315 - accuracy: 0.9918 - val_loss: 0.1589 - val_accuracy: 0.9791
# Epoch 28/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0424 - accuracy: 0.9905 - val_loss: 0.1237 - val_accuracy: 0.9831
# Epoch 29/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0377 - accuracy: 0.9911 - val_loss: 0.1120 - val_accuracy: 0.9826
# Epoch 30/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0374 - accuracy: 0.9915 - val_loss: 0.1332 - val_accuracy: 0.9817
# Epoch 31/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0370 - accuracy: 0.9913 - val_loss: 0.1236 - val_accuracy: 0.9816
# Epoch 32/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0392 - accuracy: 0.9914 - val_loss: 0.1176 - val_accuracy: 0.9829
# Epoch 33/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0393 - accuracy: 0.9908 - val_loss: 0.1475 - val_accuracy: 0.9804
# Epoch 34/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0314 - accuracy: 0.9923 - val_loss: 0.1219 - val_accuracy: 0.9815
# Epoch 35/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0364 - accuracy: 0.9919 - val_loss: 0.1152 - val_accuracy: 0.9826
# Epoch 36/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0319 - accuracy: 0.9927 - val_loss: 0.1224 - val_accuracy: 0.9814
# Epoch 37/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0335 - accuracy: 0.9927 - val_loss: 0.1306 - val_accuracy: 0.9832
# Epoch 38/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0332 - accuracy: 0.9924 - val_loss: 0.1362 - val_accuracy: 0.9834
# Epoch 39/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0407 - accuracy: 0.9926 - val_loss: 0.1497 - val_accuracy: 0.9810
# Epoch 40/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0355 - accuracy: 0.9922 - val_loss: 0.1407 - val_accuracy: 0.9832
# Epoch 41/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0345 - accuracy: 0.9928 - val_loss: 0.1281 - val_accuracy: 0.9835
# Epoch 42/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0383 - accuracy: 0.9921 - val_loss: 0.1293 - val_accuracy: 0.9830
# Epoch 43/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0368 - accuracy: 0.9921 - val_loss: 0.1459 - val_accuracy: 0.9835
# Epoch 44/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0385 - accuracy: 0.9921 - val_loss: 0.1760 - val_accuracy: 0.9814
# Epoch 45/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0331 - accuracy: 0.9930 - val_loss: 0.1504 - val_accuracy: 0.9826
# Epoch 46/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0348 - accuracy: 0.9925 - val_loss: 0.1561 - val_accuracy: 0.9847
# Epoch 47/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0308 - accuracy: 0.9934 - val_loss: 0.1662 - val_accuracy: 0.9848
# Epoch 48/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0339 - accuracy: 0.9938 - val_loss: 0.1677 - val_accuracy: 0.9822
# Epoch 49/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0384 - accuracy: 0.9928 - val_loss: 0.1718 - val_accuracy: 0.9834
# Epoch 50/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0313 - accuracy: 0.9938 - val_loss: 0.1448 - val_accuracy: 0.9842
# CPU times: total: 1h 10min 19s
# Wall time: 15min 20s

# %%
# fig, loss_ax = plt.subplots(figsize=(12,6))
# loss_ax.plot(hist.history['loss'], 'y', label='train loss')
# loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
# acc_ax = loss_ax.twinx()
# acc_ax.plot(hist.history['accuracy'], 'g', label='train accuracy')
# acc_ax.plot(hist.history['val_accuracy'], 'b', label='val accuracy')
# loss_ax.set_xlabel('epochs')
# loss_ax.set_ylabel('loss')
# acc_ax.set_ylabel('accuracy')
# loss_ax.legend(loc='center right')
# acc_ax.legend()
# plt.show()

# %%
model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1452 - accuracy: 0.9831
# [0.14522232115268707, 0.9830999970436096]

# %%
# 혼동행렬
from sklearn.metrics import confusion_matrix
print('실제값 :', y_test)
print('실제값 :', np.argmax(Y_test, axis=1))
yhat = model.predict(X_test).argmax(axis=1)
cmatrix = confusion_matrix(y_test, yhat)
cmatrix
# Out:
# 실제값 : [7 2 1 ... 4 5 6]
# 실제값 : [7 2 1 ... 4 5 6]
# 313/313 [==============================] - 1s 4ms/step
# array([[ 972,    1,    1,    0,    0,    0,    4,    1,    1,    0],
#        [   1, 1128,    0,    1,    0,    1,    4,    0,    0,    0],
#        [   0,    4, 1013,    4,    2,    0,    2,    4,    3,    0],
#        [   0,    0,    5,  995,    0,    3,    0,    3,    2,    2],
#        [   0,    0,    2,    0,  968,    0,    5,    2,    0,    5],
#        [   2,    0,    0,    7,    0,  874,    4,    0,    3,    2],
#        [   2,    2,    0,    0,    5,    1,  947,    0,    1,    0],
#        [   2,    5,    9,    1,    0,    0,    0, 1004,    3,    4],
#        [   2,    2,    4,    3,    2,    4,    1,    3,  951,    2],
#        [   3,    3,    1,    2,   13,    1,    0,    6,    1,  979]],
#       dtype=int64)

# %%
# 실제값과 예측값이 다른 갯수(방법1)
cnt = 0
for i, row in enumerate(cmatrix):
    for j, data in enumerate(row):
        if i!=j:
            cnt += data
print('예측이 틀린 갯수 :', cnt)
# Out:
# 예측이 틀린 갯수 : 169

# %%
# 실제값과 예측값이 다른 갯수(방법2)
cnt = 0
for y, h in zip(y_test, yhat):
    if y!=h:
        cnt += 1
print('예측이 틀린 갯수 :', cnt)
# Out:
# 예측이 틀린 갯수 : 169

# %%
# CNN을 사용하여 예측이 틀린 데이터 출력(yhat과 y_test가 다른 것들 169개)
plt_row = 17
plt_col = 10
plt.rcParams['figure.figsize'] = [plt_col, plt_row]
plt.rc("font", family="Malgun Gothic") # window에서 한글 시각화
# plt.rc("font", family="NanumBarunGothic") # 코랩에서 한글 시각화
fig, axes = plt.subplots(plt_row, plt_col)

i = 0 # yhat과 y_test의 index => yhat[i], y_test[i]를 비교. 
cnt = 0 # 이미지 출력 횟수

while (i<len(y_test)) & (cnt<plt_row*plt_col):
    if yhat[i] == y_test[i]:
        i += 1
        continue
    subax = axes[cnt//plt_col, cnt%plt_col] # // : 몫연산자, % : 나머지연산자
    subax.imshow(X_test[i].reshape(width, height))
    subax.axis('off')
    title = "y:{}/h:{}({})".format(y_test[i], yhat[i], i)
    subax.set_title(title)
    cnt += 1 # 이미지 출력 번호 증가
    i += 1 # index 번호 증가
plt.tight_layout()

# %% [markdown]
# # 2. CNN(컨볼루션 레이어 포함) - 교안 31page

# %%
# 1. 데이터 생성 및 전처리
width = 28; height = 28
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_val = X_train[50000:]
y_val = y_train[50000:]
X_train = X_train[:50000]
y_train = y_train[:50000]
# 독립변수 (28,28) => 784 1차원으로 -> 실수형변환 -> 스케일조정
X_train = X_train.reshape(-1, width*height).astype('float32')/255.0
X_val = X_val.reshape(-1, width*height).astype('float32')/255.0
X_test = X_test.reshape(-1, width*height).astype('float32')/255.0
# 타겟변수 원핫인코딩
Y_train = to_categorical(y_train)
Y_val = to_categorical(y_val)
Y_test = to_categorical(y_test)

X_train.shape, Y_train.shape, X_val.shape, Y_val.shape, X_test.shape, Y_test.shape
# Out:
# ((50000, 784),
#  (50000, 10),
#  (10000, 784),
#  (10000, 10),
#  (10000, 784),
#  (10000, 10))

# %%
# 2. 모델 생성
