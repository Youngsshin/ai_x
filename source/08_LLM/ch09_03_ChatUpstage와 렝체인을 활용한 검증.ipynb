# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror{font-family:Consolas; font-size:15pt;}
div.output{font-size:12pt; font-weight:bold;}
div.input{font-family:Consolas; font-size:12pt;}
div.prompt{min-width:70px;}
div#toc-wrapper {padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror{font-family:Consolas; font-size:15pt;}
# div.output{font-size:12pt; font-weight:bold;}
# div.input{font-family:Consolas; font-size:12pt;}
# div.prompt{min-width:70px;}
# div#toc-wrapper {padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# # 1. 환경(패키지 및 환경변수)
# - pip install langchain-upstage

# %%
# %pip install -q langchain-upstage
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # 2. LLM 답변 생성
# ## 2.1 OpenAI SDK를 사용

# %%
from openai import OpenAI # openai==1.52.2
import os
upstage_api_key = os.getenv("UPSTAGE_API_KEY")
 
client = OpenAI(
    api_key=upstage_api_key,
    base_url="https://api.upstage.ai/v1"
)
 
stream = client.chat.completions.create(
    model="solar-pro2",
    messages=[
        {
            "role": "user",
            "content": "2020년 월드 시리즈 누가 우승했어?"
        }
    ],
    stream=False,
)

# %%
print(stream.choices[0].message.content)
# Out:
# 2020년 월드 시리즈는 **로스앤젤레스 다저스**가 우승했습니다.
# 다저스는 탬파베이 레이스를 **4승 2패**로 꺾고, 32년 만에 통산 28번째 월드 시리즈 타이틀을 획득했습니다.
#
# - **MVP**: 다저스의 불펜 투수 **코리 시거**(당시 21세)가 시리즈 MVP를 수상했습니다.
# - **특이사항**: 코로나19 영향으로 중립 구장(텍사스 주 글로브 라이프 필드)에서 개최되었으며, 확장된 포스트시즌 형식으로 진행되었습니다.
#
# 다저스는 2020년 정규 시즌 43승 14패(MLB 최고 승률)로 포스트시즌에 진출했습니다.

# %% [markdown]
# ## 2.2 LangChain을 선택
# - 발급받은 API Key를 .env에 UPSTAGE_API_KEY라고 저장하면 별도의 설정없이 ChatUpstage를 바로 사용

# %%
from langchain_upstage import ChatUpstage
from langchain_core.messages import SystemMessage, HumanMessage
llm = ChatUpstage()
messages = [
    SystemMessage(content="너는 친절하게 대답해 주는 비서야"),
    HumanMessage(content="2020년 월드 시리즈 누가 우승했어?")
]
ai_message = llm.invoke(input=messages)
ai_message
# Out:
# AIMessage(content='2020년 월드 시리즈는 로스앤젤레스 다저스가 우승했습니다. 이는 다저스의 7번째 월드 시리즈 우승이었으며, 마지막 우승으로부터 32년 만의 성공이었습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 45, 'prompt_tokens': 36, 'total_tokens': 81, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'solar-mini-250422', 'system_fingerprint': None, 'id': '8b45dcb1-3611-4b57-aa28-6edd03eb6366', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--ceee6fb1-fec7-47ce-aae8-8e0210d0a443-0', usage_metadata={'input_tokens': 36, 'output_tokens': 45, 'total_tokens': 81, 'input_token_details': {}, 'output_token_details': {}})

# %%
ai_message.content
# Out:
# '2020년 월드 시리즈는 로스앤젤레스 다저스가 우승했습니다. 이는 다저스의 7번째 월드 시리즈 우승이었으며, 마지막 우승으로부터 32년 만의 성공이었습니다.'
